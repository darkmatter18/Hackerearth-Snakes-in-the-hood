# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
def check_size_and_view_img(fname):
    img = mpimg.imread(fname)
    print(img.shape)
    plt.imshow(img)

# %%
check_size_and_view_img('../dataset/train/0002023e6f.jpg')
# Out:
# (88, 128, 3)

# %%
check_size_and_view_img('../dataset/train/0029db90b6.jpg')
# Out:
# (171, 128, 3)

# %%
check_size_and_view_img('../dataset/train/002e7d41d2.jpg')
# Out:
# (128, 128, 3)

# %%
img = mpimg.imread('../dataset/train/0002023e6f.jpg')

# %%
from PIL import Image
pilimg = Image.open('../dataset/train/0002023e6f.jpg')

# %%
img.reshape((128,128,3))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-a544665d0da8> in <module>
# ----> 1 img.reshape((128,128,3))
#
# ValueError: cannot reshape array of size 33792 into shape (128,128,3)

# %%
from torchvision.transforms import Resize, RandomRotation, RandomCrop, RandomHorizontalFlip, CenterCrop

# %%
RandomHorizontalFlip()(RandomCrop(128)())
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x2741664AF70>

# %%
CenterCrop(224)(RandomHorizontalFlip()(RandomRotation(20)(Resize((256,256))(pilimg))))
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FEFC7005DD0>

# %%
import pandas as pd

# %%
pd.read_csv('../dataset/train.csv').values.ndim
# Out:
# 2
