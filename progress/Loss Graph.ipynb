# %%
import pickle
import matplotlib.pyplot as plt

# %%
with open('../checkpoints/resnet1606820697/loss_stats_1606820700.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
with open('../checkpoints/resnet1606052074/loss_stats_1606052077.pkl', 'rb') as f:
    data2 = pickle.load(f)

# %%
with open('./checkpoints/uwie/loss_stats_1606035925.pkl', 'rb') as f:
    data3 = pickle.load(f)

# %%
plt.figure(figsize=(20, 10))
plt.plot(data['train_loss'], label='train_loss')
plt.plot(data['test_loss'], label='test_loss')
# plt.plot(data2['train_loss'], label='train_loss_new')
# plt.plot(data2['test_loss'], label='test_loss_new')
# plt.plot(data3['train_loss'], label='train_loss_new2')
# plt.plot(data3['test_loss'], label='test_loss_new2')
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20, 10))
plt.plot(data['f1_score'], label='f1_score')
# plt.plot(data2['f1_score'], label='f1_score_new')
plt.grid()
plt.legend()
plt.show()
